# %% [markdown]
# <a href="https://colab.research.google.com/github/abkanapa-dotcom/python-Datascience/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.ion()
plt.isinteractive()
plt.plot([1.5, 3.0])

# %%
# Plot a line graph
plt.plot([1.5, 3.0]);

# Add labels and title
plt.title("Interactive Plot")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %%
# Plot a line graph
plt.plot([1.5, 3.0])

# Add labels and title
plt.title("Interactive Plot");
plt.xlabel("X-axis")
plt.ylabel("Y-axis")

# Add One more line graph
plt.plot([3.5, 2.5])
