# %% [markdown]
# <a href="https://colab.research.google.com/github/abkanapa-dotcom/python-Datascience/blob/main/Pandas_In_Depth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Local system: pip install pandas

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.datasets import load_breast_cancer

# %%
data = sns.load_dataset("tips")
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['sex'])
# Out:
# pandas.core.series.Series

# %%
type(data[['sex', 'day']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Customized Series

# %%
data = [10, 20, 30, 40, 50, 60]
series1 = pd.Series(data)
series1
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64

# %%
data = [10, 20, 30, 40, 50, 60]
series2 = pd.Series(data, index=['a', 'b', 'c', 'd', 'e', 'f'])
series2
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
s1 = pd.Series([10, 20, 30], index = ['a', 'b', 'c'])
s2 = pd.Series([5, 15, 25], index = ['b', 'c', 'd'])

result = s1 + s2

print(result)
# Out:
# a     NaN
# b    25.0
# c    45.0
# d     NaN
# dtype: float64

# %%
a1 = np.array([10, 20, 30])
a2 = np.array([5, 15, 25])

print(a1 + a2)
# Out:
# [15 35 55]

# %% [markdown]
# Create a series from a NumPy array

# %%
a1
# Out:
# array([10, 20, 30])

# %%
a1_series = pd.Series(a1, index = ['a', 'b', 'c'])
a1_series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
print(a1_series.iloc[1])
# Out:
# 20

# %%
print(a1_series.loc['b'])
# Out:
# 20

# %% [markdown]
# Create a series from a dictionary

# %%
data = {'Alice':30, 'Bob':35, 'Charlie':28}

series = pd.Series(data)
print(series)
# Out:
# Alice      30
# Bob        35
# Charlie    28
# dtype: int64

# %%
dataframe = pd.DataFrame([data])
dataframe
# Out:
#    Alice  Bob  Charlie
# 0     30   35       28

# %%
data
# Out:
# {'Alice': 30, 'Bob': 35, 'Charlie': 28}

# %%
data = pd.read_excel('/content/customers.xlsx')

# head() method used to access the top 5 records in a given dataframe
data.head()
# Out:
#    id first_name   last_name                      email  gender  street_num  \
# 0   1     Romain   Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2     Cosimo   Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi     Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4     Roarke  Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5    Mikaela    Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state  postcode
# 0   Trailsway          Road    San Diego  California   92127.0
# 1         NaN           NaN      El Paso       Texas       NaN
# 2    Arkansas        Circle  San Antonio       Texas   78220.0
# 3        Debs         Point      Memphis   Tennessee   38150.0
# 4         2nd         Drive          NaN         NaN   83732.0

# %% [markdown]
# Access the columns: [email, gender, street_name, city, state]
#
# Access the rows: [1, 2, 5, 9, 12]

# %%
data.loc[(1,2,5,9,12),["email","gender","street_name","city","state"]]
# Out:
#                      email  gender  street_name         city      state
# 1    cmolyneaux1@wiley.com    Male          NaN      El Paso      Texas
# 2   bwestrip2@symantec.com  Female     Arkansas  San Antonio      Texas
# 5         mcullip5@tiny.cc  Female      Packers    Baltimore   Maryland
# 9       spoulden9@xing.com  Female         Pond  New Orleans  Louisiana
# 12     mmacwhanc@patch.com    Male  Eagle Crest        Bronx   New York

# %% [markdown]
# iloc vs loc -> to access the values in a given dataframe

# %%
data.iloc[[1,2,5,9,12],[3,4,6,8,9]]
# Out:
#                      email  gender  street_name         city      state
# 1    cmolyneaux1@wiley.com    Male          NaN      El Paso      Texas
# 2   bwestrip2@symantec.com  Female     Arkansas  San Antonio      Texas
# 5         mcullip5@tiny.cc  Female      Packers    Baltimore   Maryland
# 9       spoulden9@xing.com  Female         Pond  New Orleans  Louisiana
# 12     mmacwhanc@patch.com    Male  Eagle Crest        Bronx   New York

# %% [markdown]
# iloc -> you can access any row/column using the index numbers only

# %%
first_name_column = data.iloc[:, 1]

# %%
first_name_column
# Out:
# 0       Romain
# 1       Cosimo
# 2        Bambi
# 3       Roarke
# 4      Mikaela
#         ...
# 995    Merrili
# 996    Winonah
# 997      Tobit
# 998     Issiah
# 999     Elmore
# Name: first_name, Length: 1000, dtype: object

# %% [markdown]
# Access the column as 'street_name'

# %%
street_name_column = data.iloc[:, 6]

# %%
street_name_column
# Out:
# 0      Trailsway
# 1            NaN
# 2       Arkansas
# 3           Debs
# 4            2nd
#          ...
# 995     Thompson
# 996      Rowland
# 997        Basil
# 998      Kenwood
# 999      Farwell
# Name: street_name, Length: 1000, dtype: object

# %% [markdown]
# Access the rows having index number [1, 2, 3] and the column name [firstName, lastName, Gender]

# %%
data.iloc[1:4, [1, 2, 4]]
# Out:
#   first_name   last_name  gender
# 1     Cosimo   Molyneaux    Male
# 2      Bambi     Westrip  Female
# 3     Roarke  Pankettman    Male

# %% [markdown]
# loc -> to access the elements using the label-based indexing

# %%
data.loc[1:4, ['first_name', 'last_name', 'gender']]
# Out:
#   first_name   last_name  gender
# 1     Cosimo   Molyneaux    Male
# 2      Bambi     Westrip  Female
# 3     Roarke  Pankettman    Male
# 4    Mikaela    Althorpe     NaN

# %% [markdown]
# Attributes

# %%
# index -> return an index object contains the row lables of the dataframe
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# shape -> return the (number of rows, number of columns) in a given dataframe
data.shape
# Out:
# (1000, 11)

# %%
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'street_num',
#        'street_name', 'street_suffix', 'city', 'state', 'postcode'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                 int64
# first_name        object
# last_name         object
# email             object
# gender            object
# street_num       float64
# street_name       object
# street_suffix     object
# city              object
# state             object
# postcode         float64
# dtype: object

# %%
data.values
# Out:
# array([[1, 'Romain', 'Southcott', ..., 'San Diego', 'California',
#         92127.0],
#        [2, 'Cosimo', 'Molyneaux', ..., 'El Paso', 'Texas', nan],
#        [3, 'Bambi', 'Westrip', ..., 'San Antonio', 'Texas', 78220.0],
#        ...,
#        [998, 'Tobit', 'Birt', ..., 'Waterbury', 'Connecticut', 6721.0],
#        [999, 'Issiah', 'Standbrooke', ..., 'Savannah', 'Georgia',
#         31405.0],
#        [1000, 'Elmore', 'Malpas', ..., 'Atlanta', 'Georgia', 30386.0]],
#       dtype=object)

# %%
data.size
# Out:
# 11000

# %%
data.empty
# Out:
# False

# %%
data.ndim
# Out:
# 2

# %% [markdown]
# Functions in a dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   first_name     1000 non-null   object
#  2   last_name      1000 non-null   object
#  3   email          878 non-null    object
#  4   gender         957 non-null    object
#  5   street_num     738 non-null    float64
#  6   street_name    963 non-null    object
#  7   street_suffix  963 non-null    object
#  8   city           921 non-null    object
#  9   state          920 non-null    object
#  10  postcode       843 non-null    float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 86.1+ KB

# %%
data.isnull().sum()
# Out:
# id                 0
# first_name         0
# last_name          0
# email            122
# gender            43
# street_num       262
# street_name       37
# street_suffix     37
# city              79
# state             80
# postcode         157
# dtype: int64

# %%
data.head(20)
# Out:
#     id  first_name      last_name                        email  gender  \
# 0    1      Romain      Southcott    rsouthcott0@clickbank.net    Male
# 1    2      Cosimo      Molyneaux        cmolyneaux1@wiley.com    Male
# 2    3       Bambi        Westrip       bwestrip2@symantec.com  Female
# 3    4      Roarke     Pankettman       rpankettman3@wiley.com    Male
# 4    5     Mikaela       Althorpe             malthorpe4@51.la     NaN
# 5    6   Magdalena         Cullip             mcullip5@tiny.cc  Female
# 6    7    Marietta         Heball            mheball6@blog.com  Female
# 7    8        Tine      McSperrin  tmcsperrin7@statcounter.com     NaN
# 8    9  Enrichetta     de Villier         edevillier8@ox.ac.uk  Female
# 9   10        Sari        Poulden           spoulden9@xing.com  Female
# 10  11      Natale        Martina      nmartinaa@wordpress.com    Male
# 11  12        Noni     Norrington    nnorringtonb@netvibes.com  Female
# ...

# %%
data.tail()
# Out:
#        id first_name    last_name                           email  gender  \
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# 995         0.0    Thompson           Way       Reading  Pennsylvania
# 996       701.0     Rowland          Hill  Indianapolis       Indiana
# 997         2.0       Basil          Road     Waterbury   Connecticut
# 998         NaN     Kenwood         Drive      Savannah       Georgia
# 999       205.0     Farwell          Park       Atlanta       Georgia
#
#      postcode
# 995   19610.0
# 996   46278.0
# 997    6721.0
# 998   31405.0
# 999   30386.0

# %%
data.tail(20)
# Out:
#        id first_name    last_name                           email  gender  \
# 980   981     Phylys     Taggerty             ptaggertyr8@epa.gov  Female
# 981   982     Judith        Otham                             NaN  Female
# 982   983    Allison       Coogan           acooganra@auda.org.au  Female
# 983   984     Adolph    Hammerton      ahammertonrb@quantcast.com    Male
# 984   985     Tailor      Sealeaf              tsealeafrc@irs.gov    Male
# 985   986      Lidia      Glendza       lglendzard@techcrunch.com  Female
# 986   987       Eric    Mountford       emountfordre@blogspot.com    Male
# 987   988   Angelica     Ludlamme             aludlammerf@unc.edu  Female
# 988   989   Vivianne       Abbyss       vabbyssrg@squarespace.com  Female
# 989   990       Mari     Carberry      mcarberryrh@eventbrite.com  Female
# 990   991     Susana         Pere              spereri@scribd.com  Female
# 991   992     Silvie   Silverlock                   ssilverlockrj  Female
# ...

# %%
data
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %% [markdown]
# Summary of the descriptive statistics

# %%
data.describe()
# Out:
#                 id    street_num      postcode
# count  1000.000000    738.000000    843.000000
# mean    500.500000  10536.439024  52669.548043
# std     288.819436  23050.537603  28140.041026
# min       1.000000      0.000000    214.000000
# 25%     250.750000     21.000000  29279.500000
# 50%     500.500000    445.500000  48232.000000
# 75%     750.250000   6918.500000  78337.500000
# max    1000.000000  99918.000000  99812.000000

# %%
data.describe(include='all')
# Out:
#                  id first_name last_name                           email  \
# count   1000.000000       1000      1000                             878
# unique          NaN        932       993                             878
# top             NaN      Berty  Sedworth  istandbrookerq@yellowpages.com
# freq            NaN          4         3                               1
# mean     500.500000        NaN       NaN                             NaN
# std      288.819436        NaN       NaN                             NaN
# min        1.000000        NaN       NaN                             NaN
# 25%      250.750000        NaN       NaN                             NaN
# 50%      500.500000        NaN       NaN                             NaN
# 75%      750.250000        NaN       NaN                             NaN
# max     1000.000000        NaN       NaN                             NaN
#
#        gender    street_num    street_name street_suffix        city  state  \
# ...

# %%
data.transpose()
# Out:
#                                      0                      1    \
# id                                     1                      2
# first_name                        Romain                 Cosimo
# last_name                      Southcott              Molyneaux
# email          rsouthcott0@clickbank.net  cmolyneaux1@wiley.com
# gender                              Male                   Male
# street_num                           1.0                    NaN
# street_name                    Trailsway                    NaN
# street_suffix                       Road                    NaN
# city                           San Diego                El Paso
# state                         California                  Texas
# postcode                         92127.0                    NaN
#
#                                   2                       3    \
# id                                  3                       4
# first_name                      Bambi                  Roarke
# ...

# %%
df_cat = data.select_dtypes(include='object')
df_cat
# Out:
#     first_name    last_name                           email  gender  \
# 0       Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2        Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4      Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..         ...          ...                             ...     ...
# 995    Merrili        Alman            malmanrn@cornell.edu  Female
# 996    Winonah       Heckle               whecklero@fc2.com  Female
# 997      Tobit         Birt                             NaN    Male
# 998     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999     Elmore       Malpas                             NaN    Male
#
#     street_name street_suffix          city         state
# 0     Trailsway          Road     San Diego    California
# ...

# %%
df_num = data.select_dtypes(include=['int64', 'float64'])
df_num
# Out:
#        id  street_num  postcode
# 0       1         1.0   92127.0
# 1       2         NaN       NaN
# 2       3      4057.0   78220.0
# 3       4        74.0   38150.0
# 4       5         NaN   83732.0
# ..    ...         ...       ...
# 995   996         0.0   19610.0
# 996   997       701.0   46278.0
# 997   998         2.0    6721.0
# 998   999         NaN   31405.0
# 999  1000       205.0   30386.0
#
# [1000 rows x 3 columns]

# %%
df_num = data.select_dtypes(include='number')
df_num
# Out:
#        id  street_num  postcode
# 0       1         1.0   92127.0
# 1       2         NaN       NaN
# 2       3      4057.0   78220.0
# 3       4        74.0   38150.0
# 4       5         NaN   83732.0
# ..    ...         ...       ...
# 995   996         0.0   19610.0
# 996   997       701.0   46278.0
# 997   998         2.0    6721.0
# 998   999         NaN   31405.0
# 999  1000       205.0   30386.0
#
# [1000 rows x 3 columns]

# %% [markdown]
# Operations on rows and columns in a dataframe

# %%
data
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %% [markdown]
# Add a new column in a dataframe

# %%
data['Country'] = 'USA'
data
# Out:
#        id first_name    last_name                           email  gender  \
# 0       1     Romain    Southcott       rsouthcott0@clickbank.net    Male
# 1       2     Cosimo    Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3      Bambi      Westrip          bwestrip2@symantec.com  Female
# 3       4     Roarke   Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela     Althorpe                malthorpe4@51.la     NaN
# ..    ...        ...          ...                             ...     ...
# 995   996    Merrili        Alman            malmanrn@cornell.edu  Female
# 996   997    Winonah       Heckle               whecklero@fc2.com  Female
# 997   998      Tobit         Birt                             NaN    Male
# 998   999     Issiah  Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000     Elmore       Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %% [markdown]
# Observation: Pandas expects that the length of the membership_status list should be exactly equivalent to the number of rows or it could be a single value which is applicable to all the rows or it could be some logic which is applicable for all the rows. Otherwise, it will throw an error.

# %%
membership_status = ['Gold', 'Silver', 'Bronze']
data['Membership Status'] = membership_status
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2075059859.py in <cell line: 0>()
#       1 membership_status = ['Gold', 'Silver', 'Bronze']
# ----> 2 data['Membership Status'] = membership_status
#       3 data
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    4309         else:
#    4310             # set column
# -> 4311             self._set_item(key, value)
#    4312
#    4313     def _setitem_slice(self, key: slice, value) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    4522         ensure homogeneity.
#    4523         """
# -> 4524         value, refs = self._sanitize_column(value)
#    4525
#    4526         if (
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    5264
# ...

# %% [markdown]
# Create a new column named 'full_name' which is composed of first_name and last_name and that too after last_name column

# %%
data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'street_num',
#        'street_name', 'street_suffix', 'city', 'state', 'postcode', 'Country'],
#       dtype='object')

# %% [markdown]
# get_loc() functions is used to access the index of the last_name column

# %%
idx = data.columns.get_loc('last_name')
print(idx)
# Out:
# 2

# %%
new_col_idx = data.columns.get_loc('last_name') + 1
data.insert(
    loc = new_col_idx,
    column = 'full_name',
    value = data['first_name'] + ' ' + data['last_name']
)

data
# Out:
#        id first_name    last_name           full_name  \
# 0       1     Romain    Southcott    Romain Southcott
# 1       2     Cosimo    Molyneaux    Cosimo Molyneaux
# 2       3      Bambi      Westrip       Bambi Westrip
# 3       4     Roarke   Pankettman   Roarke Pankettman
# 4       5    Mikaela     Althorpe    Mikaela Althorpe
# ..    ...        ...          ...                 ...
# 995   996    Merrili        Alman       Merrili Alman
# 996   997    Winonah       Heckle      Winonah Heckle
# 997   998      Tobit         Birt          Tobit Birt
# 998   999     Issiah  Standbrooke  Issiah Standbrooke
# 999  1000     Elmore       Malpas       Elmore Malpas
#
#                               email  gender  street_num street_name  \
# 0         rsouthcott0@clickbank.net    Male         1.0   Trailsway
# 1             cmolyneaux1@wiley.com    Male         NaN         NaN
# 2            bwestrip2@symantec.com  Female      4057.0    Arkansas
# ...

# %% [markdown]
# Add a new row

# %%
data.loc['1000'] = [1001,'Romain', 'Westrip', 'bwestrip52@symantec.com', 'Male', 90.0, None,None, None, 'Georgia', 83732.0, 'USA', 'Romain Westrip']
data.tail()
# Out:
# /tmp/ipython-input-2071127949.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data.loc['1000'] = [1001,'Romain', 'Westrip', 'bwestrip52@symantec.com', 'Male', 90.0, None,None, None, 'Georgia', 83732.0, 'USA', 'Romain Westrip']
#         id first_name    last_name                full_name  \
# 996    997    Winonah       Heckle           Winonah Heckle
# 997    998      Tobit         Birt               Tobit Birt
# 998    999     Issiah  Standbrooke       Issiah Standbrooke
# 999   1000     Elmore       Malpas            Elmore Malpas
# 1000  1001     Romain      Westrip  bwestrip52@symantec.com
#
#                                email  gender  street_num street_name  \
# ...

# %% [markdown]
# Delete row/column in a given dataframe

# %%
data.tail()
# Out:
#         id first_name    last_name                full_name  \
# 996    997    Winonah       Heckle           Winonah Heckle
# 997    998      Tobit         Birt               Tobit Birt
# 998    999     Issiah  Standbrooke       Issiah Standbrooke
# 999   1000     Elmore       Malpas            Elmore Malpas
# 1000  1001     Romain      Westrip  bwestrip52@symantec.com
#
#                                email  gender  street_num street_name  \
# 996                whecklero@fc2.com  Female       701.0     Rowland
# 997                              NaN    Male         2.0       Basil
# 998   istandbrookerq@yellowpages.com    Male         NaN     Kenwood
# 999                              NaN    Male       205.0     Farwell
# 1000                            Male    90.0         NaN        None
#
#      street_suffix          city        state postcode         Country
# 996           Hill  Indianapolis      Indiana  46278.0             USA
# ...

# %% [markdown]
# Drop a row

# %%
data.drop(index='1000', inplace=True)
data.tail()
# Out:
#        id first_name    last_name           full_name  \
# 995   996    Merrili        Alman       Merrili Alman
# 996   997    Winonah       Heckle      Winonah Heckle
# 997   998      Tobit         Birt          Tobit Birt
# 998   999     Issiah  Standbrooke  Issiah Standbrooke
# 999  1000     Elmore       Malpas       Elmore Malpas
#
#                               email  gender  street_num street_name  \
# 995            malmanrn@cornell.edu  Female         0.0    Thompson
# 996               whecklero@fc2.com  Female       701.0     Rowland
# 997                             NaN    Male         2.0       Basil
# 998  istandbrookerq@yellowpages.com    Male         NaN     Kenwood
# 999                             NaN    Male       205.0     Farwell
#
#     street_suffix          city         state postcode Country
# 995           Way       Reading  Pennsylvania  19610.0     USA
# 996          Hill  Indianapolis       Indiana  46278.0     USA
# ...

# %% [markdown]
# Drop a column

# %%
data.drop(columns=['first_name', 'last_name'], inplace=True)
data.head()
# Out:
#    id          full_name                      email  gender  street_num  \
# 0   1   Romain Southcott  rsouthcott0@clickbank.net    Male         1.0
# 1   2   Cosimo Molyneaux      cmolyneaux1@wiley.com    Male         NaN
# 2   3      Bambi Westrip     bwestrip2@symantec.com  Female      4057.0
# 3   4  Roarke Pankettman     rpankettman3@wiley.com    Male        74.0
# 4   5   Mikaela Althorpe           malthorpe4@51.la     NaN         NaN
#
#   street_name street_suffix         city       state postcode Country
# 0   Trailsway          Road    San Diego  California  92127.0     USA
# 1         NaN           NaN      El Paso       Texas      NaN     USA
# 2    Arkansas        Circle  San Antonio       Texas  78220.0     USA
# 3        Debs         Point      Memphis   Tennessee  38150.0     USA
# 4         2nd         Drive          NaN         NaN  83732.0     USA

# %% [markdown]
# Rename row label of first row to 'FirstCustomer'

# %%
data.rename(index = {0: 'FirstCustomer'}, inplace=True)
data
# Out:
#                  id           full_name                           email  \
# FirstCustomer     1    Romain Southcott       rsouthcott0@clickbank.net
# 1                 2    Cosimo Molyneaux           cmolyneaux1@wiley.com
# 2                 3       Bambi Westrip          bwestrip2@symantec.com
# 3                 4   Roarke Pankettman          rpankettman3@wiley.com
# 4                 5    Mikaela Althorpe                malthorpe4@51.la
# ...             ...                 ...                             ...
# 995             996       Merrili Alman            malmanrn@cornell.edu
# 996             997      Winonah Heckle               whecklero@fc2.com
# 997             998          Tobit Birt                             NaN
# 998             999  Issiah Standbrooke  istandbrookerq@yellowpages.com
# 999            1000       Elmore Malpas                             NaN
#
#                gender  street_num street_name street_suffix          city  \
# ...

# %%
data.rename(index = {'FirstCustomer':0}, inplace = True)
data
# Out:
#        id           full_name                           email  gender  \
# 0       1    Romain Southcott       rsouthcott0@clickbank.net    Male
# 1       2    Cosimo Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3       Bambi Westrip          bwestrip2@symantec.com  Female
# 3       4   Roarke Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela Althorpe                malthorpe4@51.la     NaN
# ..    ...                 ...                             ...     ...
# 995   996       Merrili Alman            malmanrn@cornell.edu  Female
# 996   997      Winonah Heckle               whecklero@fc2.com  Female
# 997   998          Tobit Birt                             NaN    Male
# 998   999  Issiah Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000       Elmore Malpas                             NaN    Male
#
#      street_num street_name street_suffix          city         state  \
# ...

# %% [markdown]
# Rename column label of street_num to street_number

# %%
data.rename(columns = {
    'street_num': 'street_number'
}, inplace=True)

data
# Out:
#        id           full_name                           email  gender  \
# 0       1    Romain Southcott       rsouthcott0@clickbank.net    Male
# 1       2    Cosimo Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3       Bambi Westrip          bwestrip2@symantec.com  Female
# 3       4   Roarke Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela Althorpe                malthorpe4@51.la     NaN
# ..    ...                 ...                             ...     ...
# 995   996       Merrili Alman            malmanrn@cornell.edu  Female
# 996   997      Winonah Heckle               whecklero@fc2.com  Female
# 997   998          Tobit Birt                             NaN    Male
# 998   999  Issiah Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000       Elmore Malpas                             NaN    Male
#
#      street_number street_name street_suffix          city         state  \
# ...

# %% [markdown]
# Rename the 'street_name' column to 'street_address'

# %%
data.rename(columns = {'street_name': 'Street_address'}, inplace=True)
data
# Out:
#        id           full_name                           email  gender  \
# 0       1    Romain Southcott       rsouthcott0@clickbank.net    Male
# 1       2    Cosimo Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3       Bambi Westrip          bwestrip2@symantec.com  Female
# 3       4   Roarke Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela Althorpe                malthorpe4@51.la     NaN
# ..    ...                 ...                             ...     ...
# 995   996       Merrili Alman            malmanrn@cornell.edu  Female
# 996   997      Winonah Heckle               whecklero@fc2.com  Female
# 997   998          Tobit Birt                             NaN    Male
# 998   999  Issiah Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000       Elmore Malpas                             NaN    Male
#
#      street_number Street_address street_suffix          city         state  \
# ...

# %% [markdown]
# Find unique values

# %%
unique_genders = data['gender'].unique()
unique_genders
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
count_unique_genders = data['gender'].nunique()
count_unique_genders
# Out:
# 2

# %%
products = pd.read_excel('/content/products.xlsx')
purchases = pd.read_excel('/content/purchases.xlsx')

# %%
products.head()
# Out:
#    Unnamed: 0  id                           product    cost   company
# 0           0   1              Liners - Baking Cups   $6.36  Skipfire
# 1           1   2        Nori Sea Weed - Gold Label  $85.74   Dynazzy
# 2           2   3                Bar Bran Honey Nut  $65.40      Ntag
# 3           3   4        Soup - Campbells Beef Stew  $68.16  Photojam
# 4           4   5  Wine - Shiraz Wolf Blass Premium  $87.39      Eare

# %% [markdown]
# Drop the column name: 'Unnamed: 0' from the products dataframe

# %%
products.drop(columns=['Unnamed: 0'], inplace=True)
products
# Out:
#     id                             product    cost       company
# 0    1                Liners - Baking Cups   $6.36      Skipfire
# 1    2          Nori Sea Weed - Gold Label  $85.74       Dynazzy
# 2    3                  Bar Bran Honey Nut  $65.40          Ntag
# 3    4          Soup - Campbells Beef Stew  $68.16      Photojam
# 4    5    Wine - Shiraz Wolf Blass Premium  $87.39          Eare
# 5    6  Wine - White, Riesling, Semi - Dry  $99.22      Livepath
# 6    7                        Brandy - Bar  $13.83          Oloo
# 7    8                      Onions - White  $42.19          Oozz
# 8    9         Lettuce - Baby Salad Greens  $30.01        Meevee
# 9   10                Sambuca - Ramazzotti  $88.99      Livepath
# 10  11                Coffee - Decafenated  $21.47        Meezzy
# 11  12             Lamb Leg - Bone - In Nz  $42.56     Photofeed
# 12  13                Lettuce - Spring Mix  $19.90  Twitterworks
# ...

# %%
purchases.head()
# Out:
#    Unnamed: 0  id           purch_date  customer_num  product_num  amount  \
# 0           0   1  2019-01-03 00:00:00           823           27      12
# 1           1   2  2019-01-03 00:00:00           606           28      14
# 2           2   3  2019-01-03 00:00:00           955            9      17
# 3           3   4  2019-01-03 00:00:00           577           19       3
# 4           4   5  2019-01-03 00:00:00           429            8      18
#
#       paid
# 0  $568.92
# 1  $395.36
# 2  $510.17
# 3   $68.49
# 4  $759.42

# %%
purchases.drop(columns=['Unnamed: 0'], inplace=True)
purchases.head()
# Out:
#    id           purch_date  customer_num  product_num  amount     paid
# 0   1  2019-01-03 00:00:00           823           27      12  $568.92
# 1   2  2019-01-03 00:00:00           606           28      14  $395.36
# 2   3  2019-01-03 00:00:00           955            9      17  $510.17
# 3   4  2019-01-03 00:00:00           577           19       3   $68.49
# 4   5  2019-01-03 00:00:00           429            8      18  $759.42

# %%
purchases.dtypes
# Out:
# id               int64
# purch_date      object
# customer_num     int64
# product_num      int64
# amount           int64
# paid            object
# dtype: object

# %% [markdown]
# paid -> float
#
# purch_date -> datetime

# %%
purchases['purch_date'] = pd.to_datetime(purchases['purch_date'])
purchases.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                   int64
# paid                    object
# dtype: object

# %%
purchases['amount'] = purchases['amount'].astype(float)
purchases.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                 float64
# paid                    object
# dtype: object

# %% [markdown]
# Convert the paid column to the float64 type

# %%
purchases['paid'] = purchases['paid'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-487978653.py in <cell line: 0>()
# ----> 1 purchases['paid'] = purchases['paid'].astype(float)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %% [markdown]
# Regular Expressions

# %%
purchases['paid'] = purchases['paid'].str.replace('[\$,]', '', regex=True)
purchases.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-4103447545.py:1: SyntaxWarning: invalid escape sequence '\$'
#   purchases['paid'] = purchases['paid'].str.replace('[\$,]', '', regex=True)
#    id purch_date  customer_num  product_num  amount    paid
# 0   1 2019-01-03           823           27    12.0  568.92
# 1   2 2019-01-03           606           28    14.0  395.36
# 2   3 2019-01-03           955            9    17.0  510.17
# 3   4 2019-01-03           577           19     3.0   68.49
# 4   5 2019-01-03           429            8    18.0  759.42

# %%
purchases['paid'] = purchases['paid'].astype(float)
purchases.dtypes
# Out:
# id                       int64
# purch_date      datetime64[ns]
# customer_num             int64
# product_num              int64
# amount                 float64
# paid                   float64
# dtype: object

# %%
products.dtypes
# Out:
# id          int64
# product    object
# cost       object
# company    object
# dtype: object

# %%
products.head()
# Out:
#    id                           product    cost   company
# 0   1              Liners - Baking Cups   $6.36  Skipfire
# 1   2        Nori Sea Weed - Gold Label  $85.74   Dynazzy
# 2   3                Bar Bran Honey Nut  $65.40      Ntag
# 3   4        Soup - Campbells Beef Stew  $68.16  Photojam
# 4   5  Wine - Shiraz Wolf Blass Premium  $87.39      Eare

# %%
products['cost'] = products['cost'].str.replace('[\$,]','',regex=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipython-input-524076436.py:1: SyntaxWarning: invalid escape sequence '\$'
#   products['cost'] = products['cost'].str.replace('[\$,]','',regex=True)

# %%
products['cost'] = products['cost'].astype(float)

# %%
products.dtypes
# Out:
# id           int64
# product     object
# cost       float64
# company     object
# sost        object
# dtype: object

# %% [markdown]
# Statistical Operations

# %%
purchases.mean()
# Out:
# id                           3000.5
# purch_date      2019-05-13 20:18:00
# customer_num             500.889333
# product_num               30.140667
# amount                    10.576167
# paid                     548.871353
# dtype: object

# %%
purchases['paid'].mean()
# Out:
# np.float64(548.8713533333333)

# %%
purchases.median()
# Out:
# id                           3000.5
# purch_date      2019-04-26 00:00:00
# customer_num                  511.0
# product_num                    30.0
# amount                         11.0
# paid                          422.7
# dtype: object

# %% [markdown]
# Max values

# %%
max_values = purchases.max(numeric_only = True)
print(max_values)
# Out:
# id              6000.0
# customer_num    1000.0
# product_num       60.0
# amount            20.0
# paid            1990.8
# dtype: float64

# %% [markdown]
# Sum Of Values

# %%
sum_values = purchases.sum(numeric_only = True)
print(sum_values)
# Out:
# id              18003000.00
# customer_num     3005336.00
# product_num       180844.00
# amount             63457.00
# paid             3293228.12
# dtype: float64

# %% [markdown]
# Count the number of values

# %%
# count the non-null values in each column
column_count = products.count()
print(column_count)
# Out:
# id         60
# product    60
# cost       60
# company    55
# sost       60
# dtype: int64

# %% [markdown]
# Frequency Analysis

# %%
products
# Out:
#     id                             product   cost       company    sost
# 0    1                Liners - Baking Cups   6.36      Skipfire   $6.36
# 1    2          Nori Sea Weed - Gold Label  85.74       Dynazzy  $85.74
# 2    3                  Bar Bran Honey Nut  65.40          Ntag  $65.40
# 3    4          Soup - Campbells Beef Stew  68.16      Photojam  $68.16
# 4    5    Wine - Shiraz Wolf Blass Premium  87.39          Eare  $87.39
# 5    6  Wine - White, Riesling, Semi - Dry  99.22      Livepath  $99.22
# 6    7                        Brandy - Bar  13.83          Oloo  $13.83
# 7    8                      Onions - White  42.19          Oozz  $42.19
# 8    9         Lettuce - Baby Salad Greens  30.01        Meevee  $30.01
# 9   10                Sambuca - Ramazzotti  88.99      Livepath  $88.99
# 10  11                Coffee - Decafenated  21.47        Meezzy  $21.47
# 11  12             Lamb Leg - Bone - In Nz  42.56     Photofeed  $42.56
# ...

# %%
products['product'].value_counts()
# Out:
# product
# Bar Bran Honey Nut                    2
# Cookies Oatmeal Raisin                2
# Nori Sea Weed - Gold Label            1
# Soup - Campbells Beef Stew            1
# Wine - Shiraz Wolf Blass Premium      1
# Wine - White, Riesling, Semi - Dry    1
# Brandy - Bar                          1
# Onions - White                        1
# Lettuce - Baby Salad Greens           1
# Liners - Baking Cups                  1
# Sambuca - Ramazzotti                  1
# Coffee - Decafenated                  1
# Lamb Leg - Bone - In Nz               1
# Lettuce - Spring Mix                  1
# Sausage - Chorizo                     1
# Glaze - Apricot                       1
# Squid Ink                             1
# Loaf Pan - 2 Lb, Foil                 1
# Bagel - Everything Presliced          1
# Bagel - Whole White Sesame            1
# Scotch - Queen Anne                   1
# Puree - Blackcurrant                  1
# Bread - Bagels, Plain                 1
# ...

# %%
data['gender'].value_counts()
# Out:
# gender
# Male      485
# Female    472
# Name: count, dtype: int64

# %%
data['gender'].mode()
# Out:
# 0    Male
# Name: gender, dtype: object

# %% [markdown]
# Aggregate Functions

# %%
products['cost'].aggregate(['max', 'min'])
# Out:
# max    99.54
# min     6.36
# Name: cost, dtype: float64

# %% [markdown]
# Sorting the values

# %%
sorted_purchase = purchases.sort_values(by='amount')
sorted_purchase
# Out:
#         id purch_date  customer_num  product_num  amount     paid
# 5033  5034 2019-05-17           680           23     1.0    16.27
# 86      87 2019-01-04           651           25     1.0    73.70
# 5061  5062 2019-05-18           540           52     1.0    98.74
# 3363  3364 2019-03-29           457           10     1.0    88.99
# 1825  1826 2019-10-04           948           19     1.0    22.83
# ...    ...        ...           ...          ...     ...      ...
# 5037  5038 2019-05-17           508           42    20.0  1750.20
# 10      11 2019-01-03           727           47    20.0   966.40
# 11      12 2019-01-03           589           30    20.0   459.20
# 5985  5986 2019-06-20           238           33    20.0  1644.40
# 92      93 2019-01-04           312            9    20.0   600.20
#
# [6000 rows x 6 columns]

# %%
sorted_purchase = purchases.sort_values(by='amount', ascending=False)
sorted_purchase
# Out:
#         id purch_date  customer_num  product_num  amount     paid
# 58      59 2019-01-04           577           42    20.0  1750.20
# 3351  3352 2019-03-29           809           23    20.0   325.40
# 3366  3367 2019-03-29           930           15    20.0   282.60
# 3388  3389 2019-03-29           155            1    20.0   127.20
# 3290  3291 2019-03-28           743           44    20.0   423.20
# ...    ...        ...           ...          ...     ...      ...
# 17      18 2019-01-03            40           60     1.0    41.22
# 59      60 2019-01-04           913           11     1.0    12.24
# 73      74 2019-01-04            92           41     1.0    65.35
# 95      96 2019-01-04           902           10     1.0    88.99
# 86      87 2019-01-04           651           25     1.0    73.70
#
# [6000 rows x 6 columns]

# %% [markdown]
# idxmax => is used to return the index of the first occurence of the maximum value.

# %%
products
# Out:
#     id                             product   cost       company    sost
# 0    1                Liners - Baking Cups   6.36      Skipfire   $6.36
# 1    2          Nori Sea Weed - Gold Label  85.74       Dynazzy  $85.74
# 2    3                  Bar Bran Honey Nut  65.40          Ntag  $65.40
# 3    4          Soup - Campbells Beef Stew  68.16      Photojam  $68.16
# 4    5    Wine - Shiraz Wolf Blass Premium  87.39          Eare  $87.39
# 5    6  Wine - White, Riesling, Semi - Dry  99.22      Livepath  $99.22
# 6    7                        Brandy - Bar  13.83          Oloo  $13.83
# 7    8                      Onions - White  42.19          Oozz  $42.19
# 8    9         Lettuce - Baby Salad Greens  30.01        Meevee  $30.01
# 9   10                Sambuca - Ramazzotti  88.99      Livepath  $88.99
# 10  11                Coffee - Decafenated  21.47        Meezzy  $21.47
# 11  12             Lamb Leg - Bone - In Nz  42.56     Photofeed  $42.56
# ...

# %%
idx_max_purchases = purchases.idxmax()
idx_max_purchases
# Out:
# id              5999
# purch_date      2234
# customer_num     352
# product_num       17
# amount            10
# paid             211
# dtype: int64

# %% [markdown]
# Return the average/mean value per company

# %%
group_by_company = products.groupby('company')
average_cost = group_by_company['cost'].mean()
print(average_cost)
# Out:
# company
# Aibox           56.330
# Babbleopia      63.980
# Brainsphere     22.830
# Browsezoom      41.050
# Cogibox         51.135
# Digitube         8.550
# Dynabox         99.400
# Dynazzy         85.740
# Eare            87.390
# Eazzy           74.280
# Edgeclub        40.690
# Eimbee          98.740
# Fanoodle        68.630
# Flipstorm       37.790
# Fliptune        75.320
# Gevee           62.600
# Innojam         73.700
# Jabbersphere    30.670
# Linkbuzz        95.680
# Livepath        94.105
# Meemm           65.350
# Meevee          30.010
# Meezzy          21.470
# Muxo            92.330
# Mynte           21.980
# Ntag            60.585
# Oloo            13.830
# Oodoo           37.450
# Oozz            42.190
# Photofeed       42.560
# Photojam        68.160
# Photolist       59.230
# Quatz           13.830
# Quinu           41.220
# Realcube        90.480
# Realpoint       61.990
# Skiba           36.670
# Skinder         84.200
# Skipfire         6.360
# ...

# %% [markdown]
# Concatenation -> combine dataframes along a particular axis (either rows or columns).

# %%
combined_df = pd.concat([data, purchases, products], axis=0)
print(combined_df)
# Out:
#     id          full_name                      email  gender  street_number  \
# 0    1   Romain Southcott  rsouthcott0@clickbank.net    Male            1.0
# 1    2   Cosimo Molyneaux      cmolyneaux1@wiley.com    Male            NaN
# 2    3      Bambi Westrip     bwestrip2@symantec.com  Female         4057.0
# 3    4  Roarke Pankettman     rpankettman3@wiley.com    Male           74.0
# 4    5   Mikaela Althorpe           malthorpe4@51.la     NaN            NaN
# ..  ..                ...                        ...     ...            ...
# 55  56                NaN                        NaN     NaN            NaN
# 56  57                NaN                        NaN     NaN            NaN
# 57  58                NaN                        NaN     NaN            NaN
# 58  59                NaN                        NaN     NaN            NaN
# 59  60                NaN                        NaN     NaN            NaN
#
# ...

# %%
combined_df_column_wise = pd.concat([data, purchases, products], axis=1)
print(combined_df_column_wise)
# Out:
#        id          full_name                      email  gender  \
# 0     1.0   Romain Southcott  rsouthcott0@clickbank.net    Male
# 1     2.0   Cosimo Molyneaux      cmolyneaux1@wiley.com    Male
# 2     3.0      Bambi Westrip     bwestrip2@symantec.com  Female
# 3     4.0  Roarke Pankettman     rpankettman3@wiley.com    Male
# 4     5.0   Mikaela Althorpe           malthorpe4@51.la     NaN
# ...   ...                ...                        ...     ...
# 5995  NaN                NaN                        NaN     NaN
# 5996  NaN                NaN                        NaN     NaN
# 5997  NaN                NaN                        NaN     NaN
# 5998  NaN                NaN                        NaN     NaN
# 5999  NaN                NaN                        NaN     NaN
#
#       street_number Street_address street_suffix         city       state  \
# 0               1.0      Trailsway          Road    San Diego  California
# ...

# %% [markdown]
# Merge Operation: SQL Joins

# %%
data.head()
# Out:
#    id          full_name                      email  gender  street_number  \
# 0   1   Romain Southcott  rsouthcott0@clickbank.net    Male            1.0
# 1   2   Cosimo Molyneaux      cmolyneaux1@wiley.com    Male            NaN
# 2   3      Bambi Westrip     bwestrip2@symantec.com  Female         4057.0
# 3   4  Roarke Pankettman     rpankettman3@wiley.com    Male           74.0
# 4   5   Mikaela Althorpe           malthorpe4@51.la     NaN            NaN
#
#   Street_address street_suffix         city       state postcode Country
# 0      Trailsway          Road    San Diego  California  92127.0     USA
# 1            NaN           NaN      El Paso       Texas      NaN     USA
# 2       Arkansas        Circle  San Antonio       Texas  78220.0     USA
# 3           Debs         Point      Memphis   Tennessee  38150.0     USA
# 4            2nd         Drive          NaN         NaN  83732.0     USA

# %%
purchases.head()
# Out:
#    id purch_date  customer_num  product_num  amount    paid
# 0   1 2019-01-03           823           27    12.0  568.92
# 1   2 2019-01-03           606           28    14.0  395.36
# 2   3 2019-01-03           955            9    17.0  510.17
# 3   4 2019-01-03           577           19     3.0   68.49
# 4   5 2019-01-03           429            8    18.0  759.42

# %%
merged_df = pd.merge(data, purchases, on = 'id', how = 'inner')
merged_df
# Out:
#        id           full_name                           email  gender  \
# 0       1    Romain Southcott       rsouthcott0@clickbank.net    Male
# 1       2    Cosimo Molyneaux           cmolyneaux1@wiley.com    Male
# 2       3       Bambi Westrip          bwestrip2@symantec.com  Female
# 3       4   Roarke Pankettman          rpankettman3@wiley.com    Male
# 4       5    Mikaela Althorpe                malthorpe4@51.la     NaN
# ..    ...                 ...                             ...     ...
# 995   996       Merrili Alman            malmanrn@cornell.edu  Female
# 996   997      Winonah Heckle               whecklero@fc2.com  Female
# 997   998          Tobit Birt                             NaN    Male
# 998   999  Issiah Standbrooke  istandbrookerq@yellowpages.com    Male
# 999  1000       Elmore Malpas                             NaN    Male
#
#      street_number Street_address street_suffix          city         state  \
# ...

# %%
'/content/products.xlsx'
